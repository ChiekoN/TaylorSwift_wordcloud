# %% [markdown]
# # Analysis of Taylor Swift songs!

# %% [markdown]
# Getting Spotify data:
#  - https://developer.spotify.com/documentation/web-api
#  - [Extracting Song Data From the Spotify API Using Python](https://towardsdatascience.com/extracting-song-data-from-the-spotify-api-using-python-b1e79388d50)
#
# Package:
#  - [Spotipy](https://spotipy.readthedocs.io/en/2.22.1/)

# %% [markdown]
# Getting lyric data:
#  - [lyricsgenius 3.0.1](https://pypi.org/project/lyricsgenius/?source=post_page-----a5563ef7f7b1--------------------------------)
#  - [How To Access and Use the Spotify and LyricGenius API](https://raizelb.medium.com/how-to-access-and-use-the-spotify-and-lyricgenius-api-a5563ef7f7b1)

# %%
from config import SPOTIPY_CLIENT_ID, SPOTIPY_CLIENT_SECRET, GENIUS_ACCESS_TOKEN

# %% [markdown]
# ## 1. Get data for all albums from Spotify

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import os

# %%
auth_manager = SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
artist_id = "06HL4z0CvFAxyc27GXpf02" #Taylor Swift
tay_all_albums = sp.artist_albums(artist_id, album_type='album',limit=50)

# %%
for item in tay_all_albums['items']:
    print("{} : {} --- {}".format(item['id'], item['name'], item['release_date']))
# Out:
# 1o59UpKw81iHR0HPiSkJR0 : 1989 (Taylor's Version) [Deluxe] --- 2023-10-27
# 64LU4c1nfjz1t4VnGhagcg : 1989 (Taylor's Version) --- 2023-10-26
# 5AEDGbliTTfjOB8TSm1sxt : Speak Now (Taylor's Version) --- 2023-07-07
# 1fnJ7k0bllNfL1kVdNVW1A : Midnights (The Til Dawn Edition) --- 2023-05-26
# 3lS1y25WAhcqJDATJK70Mq : Midnights (3am Edition) --- 2022-10-22
# 151w1FgRZfnKZA9FEcg9Z3 : Midnights --- 2022-10-21
# 6kZ42qRrzov54LcAk4onW9 : Red (Taylor's Version) --- 2021-11-12
# 4hDok0OAJd57SGIT8xuWJH : Fearless (Taylor's Version) --- 2021-04-09
# 6AORtDjduMM3bupSWzbTSG : evermore (deluxe version) --- 2021-01-07
# 2Xoteh7uEpea4TohMxjtaq : evermore --- 2020-12-11
# 0PZ7lAru5FDFHuirTkWe9Z : folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition] --- 2020-11-25
# 1pzvBxYgT6OVwJLtHkrdQK : folklore (deluxe version) --- 2020-08-18
# 2fenSS68JI1h4Fo296JfGr : folklore --- 2020-07-24
# 1NAmidJlEaVgA3MpcPFYGq : Lover --- 2019-08-23
# 6DEjYFkNZh67HP7R9PSZvv : reputation --- 2017-11-10
# 1MPAXuTVL2Ej5x0JHiSPq8 : reputation Stadium Tour Surprise Song Playlist --- 2017-11-09
# 1yGbNOtRIgdIiGHOEBaZWf : 1989 (Deluxe) --- 2014-01-01
# 5fy0X0JmZRZnVa2UEicIOl : 1989 --- 2014-01-01
# 1KVKqWeRuXsJDLTW0VuD29 : Red (Deluxe Edition) --- 2012-10-22
# 6fyR4wBPwLHKcRtxgd4sGh : Speak Now World Tour Live --- 2010-10-25
# 6GPyXXND6hIZpd9bRhCsFv : Speak Now (US Version) --- 2010-01-01
# 6S6JQWzUrJVcJLK4fi74Fw : Speak Now (Deluxe Package) --- 2010-01-01
# 2gP2LMVcIFgVczSJqn340t : Fearless (Platinum Edition) --- 2008-11-11
# 3EzFY9Rg0PpbADMth746zi : Fearless (Big Machine Radio Release Special) --- 2008-11-11
# 1ycoesYxIFymXWebfmz828 : Live From Clear Channel Stripped 2008 --- 2008-06-28
# 5eyZZoQEFQWRHkV2xgAeBw : Taylor Swift --- 2006-10-24

# %%
import pandas as pd

df = pd.DataFrame(tay_all_albums['items'], columns=['id', 'name', 'release_date', 'total_tracks'])

# %%
# check the data
df
# Out:
#                         id                                               name  \
# 0   1o59UpKw81iHR0HPiSkJR0                   1989 (Taylor's Version) [Deluxe]
# 1   64LU4c1nfjz1t4VnGhagcg                            1989 (Taylor's Version)
# 2   5AEDGbliTTfjOB8TSm1sxt                       Speak Now (Taylor's Version)
# 3   1fnJ7k0bllNfL1kVdNVW1A                   Midnights (The Til Dawn Edition)
# 4   3lS1y25WAhcqJDATJK70Mq                            Midnights (3am Edition)
# 5   151w1FgRZfnKZA9FEcg9Z3                                          Midnights
# 6   6kZ42qRrzov54LcAk4onW9                             Red (Taylor's Version)
# 7   4hDok0OAJd57SGIT8xuWJH                        Fearless (Taylor's Version)
# 8   6AORtDjduMM3bupSWzbTSG                          evermore (deluxe version)
# 9   2Xoteh7uEpea4TohMxjtaq                                           evermore
# 10  0PZ7lAru5FDFHuirTkWe9Z  folklore: the long pond studio sessions (from ...
# 11  1pzvBxYgT6OVwJLtHkrdQK                          folklore (deluxe version)
# 12  2fenSS68JI1h4Fo296JfGr                                           folklore
# 13  1NAmidJlEaVgA3MpcPFYGq                                              Lover
# 14  6DEjYFkNZh67HP7R9PSZvv                                         reputation
# 15  1MPAXuTVL2Ej5x0JHiSPq8     reputation Stadium Tour Surprise Song Playlist
# 16  1yGbNOtRIgdIiGHOEBaZWf                                      1989 (Deluxe)
# 17  5fy0X0JmZRZnVa2UEicIOl                                               1989
# 18  1KVKqWeRuXsJDLTW0VuD29                               Red (Deluxe Edition)
# 19  6fyR4wBPwLHKcRtxgd4sGh                          Speak Now World Tour Live
# 20  6GPyXXND6hIZpd9bRhCsFv                             Speak Now (US Version)
# 21  6S6JQWzUrJVcJLK4fi74Fw                         Speak Now (Deluxe Package)
# 22  2gP2LMVcIFgVczSJqn340t                        Fearless (Platinum Edition)
# 23  3EzFY9Rg0PpbADMth746zi       Fearless (Big Machine Radio Release Special)
# 24  1ycoesYxIFymXWebfmz828              Live From Clear Channel Stripped 2008
# 25  5eyZZoQEFQWRHkV2xgAeBw                                       Taylor Swift
#
#    release_date  total_tracks
# 0    2023-10-27            22
# 1    2023-10-26            21
# 2    2023-07-07            22
# 3    2023-05-26            23
# 4    2022-10-22            20
# 5    2022-10-21            13
# 6    2021-11-12            30
# 7    2021-04-09            26
# 8    2021-01-07            17
# 9    2020-12-11            15
# 10   2020-11-25            34
# 11   2020-08-18            17
# 12   2020-07-24            16
# 13   2019-08-23            18
# 14   2017-11-10            15
# 15   2017-11-09            46
# 16   2014-01-01            19
# 17   2014-01-01            13
# 18   2012-10-22            22
# 19   2010-10-25            16
# 20   2010-01-01            14
# 21   2010-01-01            22
# 22   2008-11-11            19
# 23   2008-11-11            26
# 24   2008-06-28             8
# 25   2006-10-24            15

# %%
# handpicked appropriate albums
eras = [1, 2, 4, 6, 7, 8, 11, 13, 14, 25]
eras_albums = df.loc[eras]

# %%
eras_albums
# Out:
#                         id                          name release_date  \
# 1   64LU4c1nfjz1t4VnGhagcg       1989 (Taylor's Version)   2023-10-26
# 2   5AEDGbliTTfjOB8TSm1sxt  Speak Now (Taylor's Version)   2023-07-07
# 4   3lS1y25WAhcqJDATJK70Mq       Midnights (3am Edition)   2022-10-22
# 6   6kZ42qRrzov54LcAk4onW9        Red (Taylor's Version)   2021-11-12
# 7   4hDok0OAJd57SGIT8xuWJH   Fearless (Taylor's Version)   2021-04-09
# 8   6AORtDjduMM3bupSWzbTSG     evermore (deluxe version)   2021-01-07
# 11  1pzvBxYgT6OVwJLtHkrdQK     folklore (deluxe version)   2020-08-18
# 13  1NAmidJlEaVgA3MpcPFYGq                         Lover   2019-08-23
# 14  6DEjYFkNZh67HP7R9PSZvv                    reputation   2017-11-10
# 25  5eyZZoQEFQWRHkV2xgAeBw                  Taylor Swift   2006-10-24
#
#     total_tracks
# 1             21
# 2             22
# 4             20
# 6             30
# 7             26
# 8             17
# 11            17
# 13            18
# 14            15
# 25            15

# %% [markdown]
# ### Save data into csv

# %%
df_all = pd.DataFrame(tay_all_albums['items'])
df_all.to_csv("taylor_all_albums.csv", index=False)

# %% [markdown]
# ## Get data for all album tracks

# %%
all_album_tracks = []
for alb_id, alb_name in zip(list(eras_albums['id']), list(eras_albums['name'])):
    album_tracks = sp.album_tracks(alb_id)
    for track in album_tracks['items']:
        all_album_tracks.append([track['id'], track['name'], alb_id, alb_name, track['track_number']])

# %%
all_album_tracks_df = pd.DataFrame(all_album_tracks, columns=["track_id", "track_name", "album_id", "album_name", "track_number"])

# %%
all_album_tracks_df.head(10)
# Out:
#                  track_id                                     track_name  \
# 0  1hR8BSuEqPCCZfv93zzzz9         Welcome To New York (Taylor's Version)
# 1  45wMBGri1PORPjM9PwFfrS                 Blank Space (Taylor's Version)
# 2  1hjRhYpWyqDpPahmSlUTlc                       Style (Taylor's Version)
# 3  045ZeOHPIzhxxsm8bq5kyE            Out Of The Woods (Taylor's Version)
# 4  6GXgd1BPD9bUpqw5AntGV5  All You Had To Do Was Stay (Taylor's Version)
# 5  3pv7Q5v2dpdefwdWIvE7yH                Shake It Off (Taylor's Version)
# 6  43y1WpBdnEy5TR9aZoSQL9            I Wish You Would (Taylor's Version)
# 7  64FzgoLZ3oXu2SriZblHic                   Bad Blood (Taylor's Version)
# 8  1K39ty6o1sHwwlZwO6a7wK              Wildest Dreams (Taylor's Version)
# 9  75W3SngKzTuoQ94uLf3y82        How You Get The Girl (Taylor's Version)
#
#                  album_id               album_name  track_number
# 0  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)             1
# 1  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)             2
# 2  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)             3
# 3  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)             4
# 4  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)             5
# 5  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)             6
# 6  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)             7
# 7  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)             8
# 8  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)             9
# 9  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)            10

# %% [markdown]
# ### save to csv

# %%
all_album_tracks_df.to_csv("taylor_all_album_tracks.csv")

# %% [markdown]
# ## Get lyrics for all the songs from Genius

# %%
import lyricsgenius

genius = lyricsgenius.Genius(GENIUS_ACCESS_TOKEN, timeout=20)
genius.remove_section_headers = True

# %%
artist_id = 1177 #Taylor Swift

# It can get up to 50 results. To get all albums exceeding 50, we need to repeat the call using paginated offset.
def download_album_info(page):
    total = 0
    arr = []
    g_albums = genius.artist_albums(artist_id, per_page=50, page=page)
    #print(page)
    for i, album_dict in enumerate(g_albums['albums']):
        print("{}, {}, {}".format(i, album_dict['name'], album_dict['id']))
        album_info = [album_dict['name'], album_dict['id']]
        total = i
        arr.append(album_info)
    
    return arr


page = 1
g_all_albums_info =[]
while True:
    albums_in_page = download_album_info(page)
    g_all_albums_info = g_all_albums_info + albums_in_page
    if len(albums_in_page) < 49:
        break
    page += 1
# Out:
# 0, The Tortured Poets Department, 1140058
# 1, The Tortured Poets Department + Bonus Track “The Albatross” , 1148040
# 2, The Tortured Poets Department (Physical Version), 1140061
# 3, The Tortured Poets Department + Bonus Track “The Bolter”, 1144980
# 4, 1989 (Taylor’s Version) [Webstore Deluxe], 1105019
# 5, 1989 (Taylor’s Version) [Deluxe], 1099677
# 6, 1989 (Taylor’s Version), 754738
# 7, 1989 (Taylor’s Version) [Tangerine Edition], 1082316
# 8, The Cruelest Summer, 1096172
# 9, Speak Now (Taylor’s Version) [Digital Deluxe], 1058580
# 10, Speak Now (Taylor’s Version), 758025
# 11, Midnights (The Late Night Edition), 1040217
# 12, Midnights (The Til Dawn Edition), 1040211
# 13, folklore: the long pond studio sessions (Record Store Day Exclusive), 1027134
# 14, The More Fearless (Taylor’s Version) Chapter, 1013718
# 15, The More Lover Chapter, 1013715
# 16, The More Red (Taylor’s Version) Chapter, 1013719
# 17, Lavender Haze (Remixes), 1008313
# 18, Lover (Live From Paris) Heart Shaped Vinyl, 1032700
# 19, Anti-Hero (Remixes) , 969188
# 20, Midnights (Apple Music Exclusive) , 959034
# 21, Midnights (Target Exclusive), 949856
# 22, Midnights, 945000
# 23, Midnights (3am Edition), 962334
# 24, Carolina (From The Motion Picture “Where The Crawdads Sing”), 921019
# 25, All Too Well (10 Minute Version) [The Short Film] - EP, 916591
# 26, the lakes - 7" Single (Record Store Day Exclusive), 873527
# 27, Red (Taylor’s Version): From The Vault Chapter , 862870
# 28, Red (Taylor’s Version): The Slow Motion Chapter , 862869
# 29, Message In A Bottle (Fat Max G Remix) (Taylor’s Version) , 862783
# 30, Red (Taylor’s Version): She Wrote A Song About Me Chapter, 861675
# 31, Red (Taylor’s Version): Could You Be The One Chapter, 859646
# 32, Red (Taylor’s Version), 758022
# 33, evermore (digitally autographed fan edition), 779383
# 34, Fearless (Taylor’s Version): The From the Vault Chapter, 776228
# 35, Fearless (Taylor’s Version): The I Remember What You Said Last Night Chapter, 775761
# 36, Fearless (Taylor’s Version): The Kissing In The Rain Chapter, 773617
# 37, Fearless (Taylor’s Version): The Halfway Out the Door Chapter, 771313
# 38, Fearless (Taylor’s Version), 734107
# 39, the “ladies lunching” chapter, 731261
# 40, evermore: the “forever is the sweetest con” chapter, 728549
# 41, evermore: the dropped your hand while dancing chapter, 725953
# 42, evermore (deluxe version), 710147
# 43, evermore (Japanese Edition), 726425
# 44, willow (the witch collection), 712513
# 45, evermore, 710140
# 46, Christmas Tree Farm - 12” Single Picture Disc, 840433
# 47, folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition], 704621
# 48, folklore: the long pond studio sessions (from the Disney+ special), 704342
# 49, cardigan + songwriting voice memo - Single, 681918
# 0, folklore: the yeah I showed up at your party chapter, 680288
# 1, folklore: the saltbox house chapter, 671810
# 2, folklore: the sleepless nights chapter , 670935
# 3, folklore: the escapism chapter, 669904
# 4, folklore (deluxe version), 659926
# 5, cardigan (cabin in candlelight version) - Single, 818290
# 6, folklore, 659925
# 7, Live from Paris, 636933
# 8, Our Song (7" Single), 1032701
# 9, Lover (Target Exclusive/Japanese Edition), 832267
# 10, Lover, 520929
# 11, Fearless (Big Machine Radio Release Special), 1034556
# 12, Speak Now (Big Machine Radio Release Special), 1034557
# 13, reputation Stadium Tour Surprise Song Playlist , 698363
# 14, Spotify Singles, 419292
# 15, reputation, 350247
# 16, 1989, 110728
# 17, 1989 (Deluxe), 621286
# 18, Red (Deluxe Version), 597875
# 19, Red, 22453
# 20, Speak Now: World Tour Live (Deluxe), 641306
# 21, Speak Now: World Tour Live, 146377
# 22, Speak Now: World Tour Live (Brazilian Edition), 641346
# 23, iTunes Essentials, 803344
# 24, Speak Now (Deluxe), 597883
# 25, Speak Now, 10982
# 26, Fearless (Platinum Edition), 350177
# 27, Fifteen - Single, 818293
# 28, Fearless (International Version), 597886
# 29, Love Story [UK CD Single] , 623366
# 30, Fearless (Japanese Edition), 597889
# 31, Fearless, 12731
# 32, Love Story - Single, 662190
# 33, Beautiful Eyes - EP, 152556
# 34, Live From Clear Channel Stripped 2008 , 627591
# 35, Live from SoHo - EP, 321310
# 36, Taylor Swift (Deluxe), 660089
# 37, Rhapsody Originals (Rhapsody exclusive), 628053
# 38, The Taylor Swift Holiday Collection - EP, 39094
# 39, Teardrops On My Guitar - EP, 545869
# 40, Taylor Swift (Best Buy Exclusive) , 628059
# 41, Napster Live (Napster Exclusive) , 863348
# 42, Taylor Swift, 12682
# 43, 2004 Demo CD (Three Songs), 371725
# 44, 2004 Demo CD, 477053
# 45, 2004–2005 Demo CD, 452945
# 46, Lucky You Demo CD, 371714
# 47, Vol. 2 Demo CD, 452948
# 48, “Taylor’s Songs” 2003 Demo, 477041
# 49, 2003 Demo, 1074305
# 0, 2003 Demo CD, 477049
# 1, 2002 Demo CD, 371726
# 2, reputation (Taylor’s Version)*, 856277
# 3, Taylor Swift (Taylor’s Version)*, 1127982
# 4, Demo CD (Covers), 895969

# %%
g_all_albums_df = pd.DataFrame(g_all_albums_info, columns=["Name", "id"])

# %%
g_all_albums_df.to_csv("all_albums_genius.csv")

# %% [markdown]
# **NOTE:** There are some variations for a certain album release (an *era*). I want to pick one album for each *era* like I didt for Spotify data.
# I tried to look them up by using `eras_albums` list, but it didn't find *Taylor's Version*.

# %%
g_all_albums_df['Name'].head(5)
# Out:
# 0                        The Tortured Poets Department
# 1    The Tortured Poets Department + Bonus Track “T...
# 2     The Tortured Poets Department (Physical Version)
# 3    The Tortured Poets Department + Bonus Track “T...
# 4            1989 (Taylor’s Version) [Webstore Deluxe]
# Name: Name, dtype: object

# %%
eras_albums['name'].head(5)
# Out:
# 1         1989 (Taylor's Version)
# 2    Speak Now (Taylor's Version)
# 4         Midnights (3am Edition)
# 6          Red (Taylor's Version)
# 7     Fearless (Taylor's Version)
# Name: name, dtype: object

# %%
# The album list from spotify and genius doesn't match because of the difference between "(Taylor's Version)" and "(Taylor’s Version).
# I need to correct it and turn it to a list
eras_albums_corrected = [n.replace("'", "’") for n in list(eras_albums['name'])]

# %%
g_eras_albums_df = g_all_albums_df[g_all_albums_df['Name'].isin(eras_albums_corrected)]

# %% [markdown]
# **NOTE: Pick only appropriate albums from the csv by hand. (There are some variations for a certain album release)**

# %%
# check the data
g_eras_albums_df
# Out:
#                             Name      id
# 6        1989 (Taylor’s Version)  754738
# 10  Speak Now (Taylor’s Version)  758025
# 23       Midnights (3am Edition)  962334
# 32        Red (Taylor’s Version)  758022
# 38   Fearless (Taylor’s Version)  734107
# 42     evermore (deluxe version)  710147
# 54     folklore (deluxe version)  659926
# 60                         Lover  520929
# 65                    reputation  350247
# 92                  Taylor Swift   12682

# %% [markdown]
# ## Get all lyrics from all albums

# %%
for g_album_id, g_album_title in zip(list(g_eras_albums_df['id']), list(g_eras_albums_df['Name'])):
    #print(g_album_id)
    g_album_noheader = genius.search_album(g_album_title, "Taylor Swift", album_id=g_album_id)
    lyrics_filename = "lyrics_" + g_album_title
    g_album_noheader.save_lyrics(lyrics_filename, overwrite=True, extension='json')
# Out:
# Searching for "1989 (Taylor’s Version)" by Taylor Swift...
# Wrote lyrics_1989 Taylors Version.json.
# Searching for "Speak Now (Taylor’s Version)" by Taylor Swift...
# Wrote lyrics_Speak Now Taylors Version.json.
# Searching for "Midnights (3am Edition)" by Taylor Swift...
# Wrote lyrics_Midnights 3am Edition.json.
# Searching for "Red (Taylor’s Version)" by Taylor Swift...
# Wrote lyrics_Red Taylors Version.json.
# Searching for "Fearless (Taylor’s Version)" by Taylor Swift...
# Wrote lyrics_Fearless Taylors Version.json.
# Searching for "evermore (deluxe version)" by Taylor Swift...
# Wrote lyrics_evermore deluxe version.json.
# Searching for "folklore (deluxe version)" by Taylor Swift...
# Wrote lyrics_folklore deluxe version.json.
# Searching for "Lover" by Taylor Swift...
# Wrote lyrics_Lover.json.
# Searching for "reputation" by Taylor Swift...
# Wrote lyrics_reputation.json.
# Searching for "Taylor Swift" by Taylor Swift...
# Wrote lyrics_Taylor Swift.json.
